# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/',
#  'https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/09/15/ai-in-production-gen-ai-and-agentic-ai-on-aws-at-scale/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'},
#   {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community discussion', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company Twitter', 'url': 'https://twitter.com/huggingface'}, {'type': 'company LinkedIn', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# ibm-granite/granite-docling-258M
# Updated
# about 23 hours ago
# •
# 25.7k
# •
# 599
# openbmb/VoxCPM-0.5B
# Updated
# 5 days ago
# •
# 3.24k
# •
# 652
# Alibaba-NLP/Tongyi-DeepResearch-30B-A3B
# Updated
# 7 days ago
# •
# 9.15k
# •
# 601
# Wan-AI/Wan2.2-Animate-14B
# Updated
# 5 days ago
# •
# 14.4k
# •
# 387
# Qwen/Qwen3-Omni-30B-A3B-Instruct
# Updated
# 1 day ago
# •
# 1.69k
# •
# 329
# Browse 1M+ models
# Spaces
# Running
# 14.2k
# 14.2k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 428
# 428
# Wan2.2 Animate
# 👁
# Wan2.2 Animate
# Running
# on
# Zero
# MCP
# 1.25k
# 1.25k
# Wan2.2 14B Fast
# 🎥
# generate a video from an image with a text prompt
# Running
# on
# Zero
# 156
# 156
# granite-docling-258M demo
# 📝
# Convert images to structured documents and answer questions
# Running
# on
# Zero
# 268
# 268
# IndexTTS 2 Demo
# 🏢
# Generate expressive speech from text with emotion control
# Browse 400k+ applications
# Datasets
# HuggingFaceFW/finepdfs
# Updated
# 16 days ago
# •
# 80.2k
# •
# 565
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 48.4k
# •
# 9.12k
# InternRobotics/OmniWorld
# Updated
# 29 minutes ago
# •
# 15.2k
# •
# 59
# LucasFang/FLUX-Reason-6M
# Updated
# 12 days ago
# •
# 38.5k
# •
# 78
# HuggingFaceM4/FineVision
# Updated
# 19 days ago
# •
# 257k
# •
# 343
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Team
# non-profit
# •
# 792 models
# •
# 4.09k followers
# AI at Meta
# Enterprise
# company
# •
# 2.23k models
# •
# 7.98k followers
# Amazon
# Enterprise
# company
# •
# 20 models
# •
# 3.44k followers
# Google
# Enterprise
# company
# •
# 1.05k models
# •
# 30.5k followers
# Intel
# company
# •
# 240 models
# •
# 3.04k followers
# Microsoft
# Enterprise
# company
# •
# 425 models
# •
# 15.6k followers
# Grammarly
# Team
# company
# •
# 11 models
# •
# 180 followers
# Writer
# Enterprise
# company
# •
# 30 models
# •
# 349 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 150,161
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,859
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,461
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,934
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 10,097
# Fast tokenizers optimized for research & production
# TRL
# 15,632
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,596
# State-of-the-art ML running directly in your browser
# smolagents
# 22,984
# Smol library to build great agents in Python
# PEFT
# 19,663
# Parameter-efficient finetuning for large language models
# Datasets
# 20,680
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,528
# Serve language models with TGI optimized toolkit
# Accelerate
# 9,154
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# ibm-granite/granite-docling-258M
# Updated
# about 23 hours ago
# •
# 25.7k
# •
# 599
# openbmb/VoxCPM-0.5B
# Updated
# 5 days ago
# •
# 3.24k
# •
# 652
# Alibaba-NLP/Tongyi-DeepResearch-30B-A3B
# Updated
# 7 days ago
# •
# 9.15k
# •
# 601
# Wan-AI/Wan2.2-Animate-14B
# Updated
# 5 days ago
# •
# 14.4k
# •
# 387
# Qwen/Qwen3-Omni-30B-A3B-Instruct
# Updated
# 1 day ago
# •
# 1.69k
# •
# 329
# Browse 1M+ models
# Spaces
# Running
# 14.2k
# 14.2k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# 428
# 428
# Wan2.2 Animate
# 👁
# Wan2.2 Animate
# Running
# on
# Zero
# MCP
# 1.25k
# 1.25k
# Wan2.2 14B Fast
# 🎥
# generate a video from an image with a text prompt
# Running
# on
# Zero
# 156
# 156
# granite-docling-258M demo
# 📝
# Convert images to structured documents and answer questions
# Running
# on
# Zero
# 268
# 268
# IndexTTS 2 Demo
# 🏢
# Generate expressive speech from text with emotion control
# Browse 400k+ applications
# Datasets
# HuggingFaceFW/finepdfs
# Updated
# 16 days ago
# •
# 80.2k
# •
# 565
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 48.4k
# •
# 9.12k
# InternRobotics/OmniWorld
# Updated
# 29 minutes ago
# •
# 15.2k
# •
# 59
# LucasFang/FLUX-Reason-6M
# Updated
# 12 days ago
# •
# 38.5k
# •
# 78
# HuggingFaceM4/FineVision
# Updated
# 19 days ago
# •
# 257k
# •
# 343
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Team
# non-profit
# •
# 792 models
# •
# 4.09k followers
# AI at Meta
# Enterprise
# company
# •
# 2.23k models
# •
# 7.98k followers
# Amazon
# Enterprise
# company
# •
# 20 models
# •
# 3.44k followers
# Google
# Enterprise
# company
# •
# 1.05k models
# •
# 30.5k followers
# Intel
# company
# •
# 240 models
# •
# 3.04k followers
# Microsoft
# Enterprise
# company
# •
# 425 models
# •
# 15.6k followers
# Grammarly
# Team
# company
# •
# 11 models
# •
# 180 followers
# Writer
# Enterprise
# company
# •
# 30 models
# •
# 349 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 150,161
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,859
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,461
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,934
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 10,097
# Fast tokenizers optimized for research & production
# TRL
# 15,632
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,596
# State-of-the-art ML running directly in your browser
# smolagents
# 22,984
# Smol library to build great agents in Python
# PEFT
# 19,663
# Parameter-efficient finetuning for large language models
# Datasets
# 20,680
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,528
# Serve language models with TGI optimized toolkit
# Accelerate
# 9,154
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# company blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Smol2Operator: Post-Training GUI Agents for Computer Use
# By
# A-Mahla
# September 23, 2025
# •
# 53
# Community Articles
# view all
# RexBERT: Encoders for a brave new world of E-Commerce
# By
# thebajajra
# and 1 other
# •
# 3 days ago
# •
# 33
# Introducing the Palmyra-mini family: Powerful, lightweight, and ready to reason!
# By
# Writer
# and 1 other
# •
# 12 days ago
# •
# 58
# mem-agent: Persistent, Human Readable Memory Agent Trained with Online RL
# By
# driaforall
# and 1 other
# •
# 13 days ago
# •
# 21
# "Anemll-style" Root-Mean-Square (RMS) Normalization on the Apple Neural Engine: A Simple Hack
# By
# anemll
# •
# 7 days ago
# •
# 10
# 🌎 What kind of environmental impacts are AI companies disclosing? (And can we compare them?) 🌎
# By
# sasha
# and 1 other
# •
# 7 days ago
# •
# 10
# Unleashing the Full Potential of ERNIE4.5 using FastDeploy
# By
# baidu
# and 3 others
# •
# 5 days ago
# •
# 10
# AtlasOCR: Building the First Open-Source Darija OCR Model with Vision Language Models
# By
# imomayiz
# and 4 others
# •
# 8 days ago
# •
# 14
# How to Train an Antibody Developability Model
# By
# ginkgo-datapoints
# and 1 other
# •
# 7 days ago
# •
# 9
# SyGra: The One-Stop Framework for Building Data for LLMs and SLMs
# By
# ServiceNow-AI
# and 3 others
# •
# 2 days ago
# •
# 9
# How to Choose the Best Open Source LLM for Your Project in 2025
# By
# dvilasuero
# •
# 15 days ago
# •
# 70
# Small Language Models (SLM): A Comprehensive Overview
# By
# jjokah
# •
# Feb 22
# •
# 72
# Nemotron-Personas-Japan: Synthesized Data for Sovereign AI
# By
# nvidia
# and 6 others
# •
# about 8 hours ago
# •
# 7
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 221
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 199
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 5 others
# •
# Jun 11
# •
# 92
# Use AI on Your PC: Optimize and Deploy a Multimodal Agentic Pipeline on AI PC Powered by Intel
# By
# estellea
# and 2 others
# •
# 7 days ago
# •
# 5
# Finegrain Product Placement LoRA (experiment)
# By
# finegrain
# •
# 6 days ago
# •
# 5
# From GRPO to DAPO and GSPO: What, Why, and How
# By
# NormalUhr
# •
# Aug 9
# •
# 30
# 🥬 TinyLettuce: Efficient Hallucination Detection with 17–68M Encoders
# By
# adaamko
# and 1 other
# •
# 24 days ago
# •
# 13
# PP-OCRv5 on Hugging Face: A Specialized Approach to OCR
# By
# baidu
# and 5 others
# •
# 14 days ago
# •
# 98
# Gaia2 and ARE: Empowering the community to study agents
# By
# clefourrier
# September 22, 2025
# •
# 62
# Scaleway on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# September 19, 2025
# •
# 14
# Democratizing AI Safety with RiskRubric.ai
# By
# galmo-noma
# September 18, 2025
# •
# 14
# Public AI on Hugging Face Inference Providers 🔥
# By
# sbrandeis
# September 17, 2025
# •
# 14
# `LeRobotDataset`: Bringing large-scale datasets to lerobot
# By
# fracapuano
# September 16, 2025
# •
# 27
# Visible Watermarking with Gradio
# By
# meg
# September 15, 2025
# •
# 12
# Tricks from OpenAI gpt-oss YOU 🫵 can use with transformers
# By
# ariG23498
# September 11, 2025
# •
# 145
# Jupyter Agents: training LLMs to reason with notebooks
# By
# baptistecolle
# September 10, 2025
# •
# 40
# mmBERT: ModernBERT goes Multilingual
# By
# orionweller
# September 9, 2025
# •
# 93
# Welcome EmbeddingGemma, Google's new efficient embedding model
# By
# tomaarsen
# September 4, 2025
# •
# 222
# Make your ZeroGPU Spaces go brrr with PyTorch ahead-of-time compilation
# By
# cbensimon
# September 2, 2025
# •
# 58
# Generate Images with Claude and Hugging Face
# By
# evalstate
# August 19, 2025
# •
# 35
# From Zero to GPU: A Guide to Building and Scaling Production-Ready CUDA Kernels
# By
# drbh
# August 18, 2025
# •
# 70
# MCP for Research: How to Connect AI to Research Tools
# By
# dylanebert
# August 18, 2025
# •
# 56
# Previous
# 1
# 2
# 3
# ...
# 46
# Next
# Community Articles
# Sort:
# 		Trending
# RexBERT: Encoders for a brave new world of E-Commerce
# By
# thebajajra
# and 1 other
# •
# 3 days ago
# •
# 33
# Introducing the Palmyra-mini family: Powerful, lightweight, and ready to reason!
# By
# Writer
# and 1 other
# •
# 12 days ago
# •
# 58
# mem-agent: Persistent, Human Readable Memory Agent Trained with Online RL
# By
# driaforall
# and 1 other
# •
# 13 days ago
# •
# 21
# "Anemll-style" Root-Mean-Square (RMS) Normalization on the Apple Neural Engine: A Simple Hack
# By
# anemll
# •
# 7 days ago
# •
# 10
# 🌎 What kind of environmental impacts are AI companies disclosing? (And can we compare them?) 🌎
# By
# sasha
# and 1 other
# •
# 7 days ago
# •
# 10
# Unleashing the Full Potential of ERNIE4.5 using FastDeploy
# By
# baidu
# and 3 others
# •
# 5 days ago
# •
# 10
# AtlasOCR: Building the First Open-Source Darija OCR Model with Vision Language Models
# By
# imomayiz
# and 4 others
# •
# 8 days ago
# •
# 14
# How to Train an Antibody Developability Model
# By
# ginkgo-datapoints
# and 1 other
# •
# 7 days ago
# •
# 9
# SyGra: The One-Stop Framework for Building Data for LLMs and SLMs
# By
# ServiceNow-AI
# and 3 others
# •
# 2 days ago
# •
# 9
# How to Choose the Best Open Source LLM for Your Project in 2025
# By
# dvilasuero
# •
# 15 days ago
# •
# 70
# Small Language Models (SLM): A Comprehensive Overview
# By
# jjokah
# •
# Feb 22
# •
# 72
# Nemotron-Personas-Japan: Synthesized Data for Sovereign AI
# By
# nvidia
# and 6 others
# •
# about 8 hours ago
# •
# 7
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 221
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 199
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 5 others
# •
# Jun 11
# •
# 92
# Use AI on Your PC: Optimize and Deploy a Multimodal Agentic Pipeline on AI PC Powered by Intel
# By
# estellea
# and 2 others
# •
# 7 days ago
# •
# 5
# Finegrain Product Placement LoRA (experiment)
# By
# finegrain
# •
# 6 days ago
# •
# 5
# From GRPO to DAPO and GSPO: What, Why, and How
# By
# NormalUhr
# •
# Aug 9
# •
# 30
# 🥬 TinyLettuce: Efficient Hallucination Detection with 17–68M Encoders
# By
# adaamko
# and 1 other
# •
# 24 days ago
# •
# 13
# PP-OCRv5 on Hugging Face: A Specialized Approach to OCR
# By
# baidu
# and 5 others
# •
# 14 days ago
# •
# 98
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company Twitter
# Webpage Title:
# No title found
# Webpage Contents:
# JavaScript is not available.
# We’ve detected that JavaScript is disabled in this browser. Please enable JavaScript or switch to a supported browser to continue using x.com. You can see a list of supported browsers in our Help Center.
# Help Center
# Terms of Service
# Privacy Policy
# Cookie Policy
# Imprint
# Ads info
# © 2025 X Corp.
# Something went wrong, but don’t fret — let’s give it another shot.
# Try again
# Some privacy related extensions may cause issues on x.com. Please disable them and try again.
#
#
#
# company LinkedIn
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Sign in
# Join now
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# Discover all 622 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Shaunak Joshi
# AI Researcher/Engineer
# 13h
# Report this post
# Remote MCP launches on Groq! 🚀
# Thrilled to debut our agent-native infrastructure showcasing
# Parallel Web Systems
# and
# Hugging Face
# tools connected through MCP. Lightning-fast performance meets OpenAI compatibility - exactly what developers building the future of AI agents need.
#
# Thanks to our amazing partners and the incredible
# Groq
# team that made this possible.
#
# Check out our blog:
# https://lnkd.in/gr3iHVS5
# …more
# 46
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 20h
# Edited
# Report this post
# Qwen3-Omni is new sota any-to-any model🔥 everything you have to know ⤵️
#
# > a 30B MoE model with 3B active params, comes in three variants: instruct, thinking and captioner 🤩 thinking is for reasoning and captioner is for robust speech generation 🗣️
# > it understands everything (image/text/audio/video) and outputs text or speech with multiple speaker options
# > understands 119 languages (text) and 19 speech  languages, and supports 10 languages for speech output! (list in model card)
# > comes with transformers + vLLM support 🤗
# > sota in most video/audio benchmarks against Gemini 2.5 Pro and GPT-4o
# find models and demos in comments!
# 339
# 16 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Qwen
# 25,236 followers
# 1d
# Report this post
# 🚀 Introducing Qwen3-Omni — the first natively end-to-end omni-modal AI unifying text, image, audio & video in one model — no modality trade-offs!
#
# 🏆 SOTA on 22/36 audio & AV benchmarks
# 🌍 119L text / 19L speech in / 10L speech out
# ⚡ 211ms latency | 🎧 30-min audio understanding
# 🎨 Fully customizable via system prompts
# 🔗 Built-in tool calling
# 🎤 Open-source Captioner model (low-hallucination!)
#
# 🌟 What’s Open-Sourced?
# We’ve open-sourced Qwen3-Omni-30B-A3B-Instruct, Qwen3-Omni-30B-A3B-Thinking, and Qwen3-Omni-30B-A3B-Captioner, to empower developers to explore a variety of applications from instruction-following to creative tasks.
#
# Try it now 👇
# 💬Qwen Chat:
# https://lnkd.in/gD3KFCPH
# 💻 GitHub:
# https://lnkd.in/gKXbW9eF
# 🤗 HF Models:
# https://lnkd.in/gE-Wrv7J
# 🤖MS Models:
# https://lnkd.in/geK5QBns
# 🎬 Demo:
# https://lnkd.in/gVNABb2X
# 4,454
# 70 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Tom Aarsen
# 🤗 Sentence Transformers & NLTK maintainer, MLE @ Hugging Face
# 1d
# Report this post
# 🛒 RexBERT: ModernBERT except for E-commerce was just released. 4 Encoders (17M, 68M, 150M, 400M) trained on 2.3T tokens (with 350B E-commerce related tokens), easily outperforming base models on E-commerce tasks! Details:
#
# - 4 encoder models by
# Rahul Bajaj
# and
# Anuj Garg
# (17M, 68M, 150M, 400M), very usable sizes and 8k sequence length.
# - RexBERT is built on top of the excellent Ettin checkpoints after its first 2 phases, which consist of pretraining (1.7T tokens) and context extension (250B) tokens. The third (annealing) phase adds 350B tokens of E-commerce related tokens from an all-new dataset called 'Econ-niverse'. The authors published this dataset as well!
# - The models are "base models", i.e. they require finetuning. In a semantic similarity test, the finetuned RexBERT models heavily outperformed other finetuned models (Ettin, ModernBERT, EmbeddingGemma) at all each size, with identical train/eval conditions.
# - Apache 2.0 license, i.e. commercially viable
#
# Definitely check out the full blogpost for all details:
# https://lnkd.in/eaPwCMaF
# I think there's two huge takeaways here:
# 1. If you're working with encoder models (search, clustering, classification) for e-commerce: use RexBERT!
# 2. If you're in a specific domain, further training Ettin or ModernBERT can be very powerful.
#
# What Rahul and Anuj did here was not easy, normally we only see models this competitive from big labs or companies. Wonderful job!
# RexBERT: Encoders for a brave new world of E-Commerce
# huggingface.co
# 312
# 10 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sergio Paniego Blanco
# ML Engineer @ Hugging Face 🤗 | AI PhD | Google Summer of Code '18-'25
# 1d
# Report this post
# This summer TRL leveled up for multimodal alignment 🌞
#
# ✅ New VLM alignment methods (MPO, GRPO, GSPO)
# ✅ Extended RLOO & Online DPO for VLMs
# ✅ Native SFT support
# ✅ Ready-to-use training scripts
#
# 🔗
# https://lnkd.in/dHwFBZzq
# 55
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 2d
# Report this post
# I will give a talk today at CBMM MIT, on recipes to optimize flow-based image and video generation models beyond speed.
#
# Details are here:
# https://lnkd.in/gUi2igBE
# I think the recording of the talk will be made available in:
# https://lnkd.in/gtt6VZCr
# Computational Tutorials
# cbmm.mit.edu
# 142
# 2 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Julien Chaumond
# CTO at Hugging Face
# 3d
# Report this post
# Your semi-regular reminder that Xet is a ground-breaking piece of tech 🔥
#
# Lets you store Large Files on the HF Hub faster, intelligently splits files into unique chunks, and accelerates both uploads and downloads.
#
# Total gamer-changer on the Hub and for the open AI field in general 🥳
# 371
# 14 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 6d
# Report this post
# BOOM! IBM just released an updated SmolDocling - tiny 258M param SoTA VLM - Apache 2.0 licensed! 🔥
#
# Capable of doing OCR, Visual QA, Translation and much more - try it out now:
# https://lnkd.in/gi8wUNsN
# 🤗
# …more
# 874
# 21 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Lysandre Debut
# COSO - Chief Open Source Officer at Hugging Face
# 4d
# Report this post
# Thinking back to the origins, BERT, ALBERT, DistilBERT all seemed so far apart
#
# Crazy to see them so tightly coupled in this timeline; we have truly come a long way since then. Encoder releases were so much more frequent than decoders back then.
#
# 409 architectures and counting!
# …more
# 264
# 7 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 69,776 followers
# 5d
# Edited
# Report this post
# BOOM!! Introducing Guided Image Edits with
# Google DeepMind
# 's Nano-Banana 😱
#
# A simple and intuitive UI to do guided and grounded image edits with your favorite AI 🔥⬇️⬇️
#
# With this app, we are also introducing
# Gradio
# 's NEW custom navbars.🔥
#
# Learn more about our gr.Navbar component here:
# https://lnkd.in/gUH-p2dX
# Guided nano-banana app on
# Hugging Face
# (FREE for next few hours😍):
# https://lnkd.in/gTv4ia8A
# The app is using the
# fal
# API to access nano-banana.💯
# …more
# 63
# 4 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Mountain View, California
# Cohere
# Software Development
# Toronto, Ontario
# NVIDIA
# Computer Hardware Manufacturing
# Santa Clara, CA
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'documentation page', 'url': 'https://huggingface.co/docs'}]}
# # Hugging Face Brochure
#
# ---
#
# ## Welcome to Hugging Face
#
# ### The AI Community Building the Future
#
# At Hugging Face, we empower the machine learning community to collaborate on models, datasets, and applications. Our platform is designed for innovators who are passionate about pushing the boundaries of artificial intelligence.
#
# ### Explore Our Offerings
#
# - **Models**: Browse over 1 million machine learning models to find the right fit for your needs.
# - **Datasets**: Access and share over 250,000 datasets for various machine learning tasks.
# - **Spaces**: Discover and run over 400,000 applications that leverage our innovative models.
# - **Enterprise Solutions**: Utilize our paid compute resources and enterprise-grade features to accelerate your projects.
#
# ### Driving Collaboration in AI
#
# Join a thriving community where you can create, discover, and collaborate on machine learning projects. We provide tools that enable teams and individuals to share their work, build portfolios, and contribute to open-source initiatives.
#
# ### Notable Customers
#
# Hugging Face proudly serves more than 50,000 organizations, including giants like:
# - Amazon
# - Google
# - Microsoft
# - Meta
# - Intel
#
# ### A Culture of Innovation
#
# Our company culture is centered around community, transparency, and excellence. We believe in giving everyone the tools they need to succeed and fostering an environment where creativity thrives.
#
# - **Open Source Philosophy**: We are at the forefront of open-source AI tooling, with popular libraries such as Transformers and Diffusers.
# - **Supportive Community**: Engage with peers in forums, contribute to discussions, and attend events to expand your knowledge and network.
#
# ### Careers at Hugging Face
#
# Join our diverse team at Hugging Face, where your contributions can help shape the future of AI. We offer a wide range of opportunities across different teams and specializations. Whether you're a developer, data scientist, or a dedicated community advocate, we would love to hear from you.
#
# - **Flexible Work Environment**: Embrace remote work opportunities with flexible hours.
# - **Growth and Development**: Participate in ongoing training and professional development programs to enhance your skills.
#
# ### Get Involved
#
# Are you ready to be part of something big? Sign up on our platform to start collaborating, building, and innovating in the world of AI.
#
# [Explore AI Apps](#) | [Browse Models](#) | [Sign Up](#)
#
# ---
#
# For more information, visit our website at [Hugging Face](https://huggingface.co).
#
# *Together, let's build the future of AI!*
#
# ---

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# # Hugging Face Company Brochure
#
# ---
#
# ## About Us
# **Hugging Face** is a community-driven platform dedicated to advancing the field of artificial intelligence (AI) and machine learning (ML). Our mission is to build the foundations of machine learning tools collaboratively and openly, fostering innovation and enhancing the capabilities of AI applications.
#
# We provide a collaborative environment where developers, researchers, and enthusiasts can work together, sharing their models, datasets, and applications, allowing everyone to contribute to the future of AI.
#
# ## Our Offerings
# - **1M+ Models**: Explore a wide range of machine learning models contributed by our community.
# - **250K+ Datasets**: Access a rich repository of datasets for various ML tasks.
# - **Spaces**: A collaborative platform for developing applications and demos in real-time.
# - **Enterprise Solutions**: Tailored for organizations requiring advanced AI capabilities, featuring enterprise-grade support and security.
#
# ## Company Culture
# At Hugging Face, we believe in inclusivity and collaboration. We empower our community to share their knowledge and innovations, fostering an environment of transparency and support. We value creativity, encourage experimentation, and celebrate success as a team.
#
# Join us in our mission to build cutting-edge AI and contribute to an open-source ecosystem where everyone can learn, innovate, and grow together.
#
# ## Community Engagement
# With over 60,600 followers and contributions from thousands of users, our community is thriving. We have engaged with various organizations, including:
# - **Google**
# - **Amazon**
# - **Microsoft**
# - **Intel**
# - **Grammarly**
#
# Our community also supports numerous projects and applications, enabling real-world utility and accessibility of AI technologies.
#
# ## Career Opportunities
# Hugging Face is expanding, and we are always on the lookout for passionate and talented individuals to join our team. We offer dynamic career opportunities that allow you to work on the cutting edge of AI. If you are interested in becoming part of a fast-paced, innovative, and supportive team, check out our [careers page](https://huggingface.co/jobs) for current openings.
#
# ## Connect with Us
# Be a part of the revolution in AI by joining the Hugging Face community today!
#
# - [Website](https://huggingface.co)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://huggingface.co/discord)
#
# Together, let’s build the future of artificial intelligence!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
